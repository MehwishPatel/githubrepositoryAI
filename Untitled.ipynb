# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.image as mpimg

from PIL import Image
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

# %%
input_name = "F:\Color.png"
output_width = 900                   #set the output size
img = Image.open(input_name)
wpercent = (output_width/float(img.size[0]))
hsize = int((float(img.size[1])*float(wpercent)))
img = img.resize((output_width,hsize), Image.ANTIALIAS)
# Out:
# C:\Users\AGM\AppData\Local\Temp\ipykernel_916\1619081525.py:6: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   img = img.resize((output_width,hsize), Image.ANTIALIAS)

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# !pip install easydev                 
# !pip install colormap                
# !pip install opencv-python          
# !pip install colorgram.py           
# !pip install extcolors              

import cv2
import extcolors

from colormap import rgb2hex
# Out:
# Requirement already satisfied: easydev in c:\users\agm\anaconda3\lib\site-packages (0.12.0)
# Requirement already satisfied: colorlog in c:\users\agm\anaconda3\lib\site-packages (from easydev) (6.7.0)
# Requirement already satisfied: pexpect in c:\users\agm\anaconda3\lib\site-packages (from easydev) (4.8.0)
# Requirement already satisfied: colorama in c:\users\agm\appdata\roaming\python\python39\site-packages (from easydev) (0.4.4)
# Requirement already satisfied: ptyprocess>=0.5 in c:\users\agm\anaconda3\lib\site-packages (from pexpect->easydev) (0.7.0)
# Requirement already satisfied: colormap in c:\users\agm\anaconda3\lib\site-packages (1.0.4)
# Requirement already satisfied: opencv-python in c:\users\agm\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\agm\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Requirement already satisfied: colorgram.py in c:\users\agm\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: pillow>=3.3.1 in c:\users\agm\appdata\roaming\python\python39\site-packages (from colorgram.py) (9.1.1)
# Requirement already satisfied: extcolors in c:\users\agm\anaconda3\lib\site-packages (1.0.0)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\agm\appdata\roaming\python\python39\site-packages (from extcolors) (9.1.1)
# Requirement already satisfied: convcolors>=1.0.0 in c:\users\agm\anaconda3\lib\site-packages (from extcolors) (2.2.0)

# %%
def exact_color(img, resize, tolerance, zoom):
    #background
    bg = 'Color.png'
    fig, ax = plt.subplots(figsize=(192,108),dpi=10)
    fig.set_facecolor('white')
    plt.savefig(bg)
    plt.close(fig)
    
    #resize
    output_width = resize
    img = Image.open(img)
    if img.size[0] >= resize:
        wpercent = (output_width/float(img.size[0]))
        hsize = int((float(img.size[1])*float(wpercent)))
        img = img.resize((output_width,hsize), Image.ANTIALIAS)
        resize_name = 'resize_'+ img
        img.save(resize_name)
    else:
        resize_name = img
    
    #crate dataframe
    img_url = resize_name
    colors_x = extcolors.extract_from_path(img_url, tolerance = tolerance, limit = 13)
    df_color = color_to_df(colors_x)
    
    #annotate text
    list_color = list(df_color['c_code'])
    list_precent = [int(i) for i in list(df_color['occurence'])]
    text_c = [c + ' ' + str(round(p*100/sum(list_precent),1)) +'%' for c, p in zip(list_color, list_precent)]
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(160,120), dpi = 10)
    
    #donut plot
    wedges, text = ax1.pie(list_precent,
                           labels= text_c,
                           labeldistance= 1.05,
                           colors = list_color,
                           textprops={'fontsize': 150, 'color':'black'})
    plt.setp(wedges, width=0.3)

    #add image in the center of donut plot
    img = mpimg.imread(resize_name)
    imagebox = OffsetImage(img, zoom=zoom)
    ab = AnnotationBbox(imagebox, (0, 0))
    ax1.add_artist(ab)
    
    #color palette
    x_posi, y_posi, y_posi2 = 160, -170, -170
    for c in list_color:
        if list_color.index(c) <= 5:
            y_posi += 180
            rect = patches.Rectangle((x_posi, y_posi), 360, 160, facecolor = c)
            ax2.add_patch(rect)
            ax2.text(x = x_posi+400, y = y_posi+100, s = c, fontdict={'fontsize': 190})
        else:
            y_posi2 += 180
            rect = patches.Rectangle((x_posi + 1000, y_posi2), 360, 160, facecolor = c)
            ax2.add_artist(rect)
            ax2.text(x = x_posi+1400, y = y_posi2+100, s = c, fontdict={'fontsize': 190})

    fig.set_facecolor('white')
    ax2.axis('off')
    bg = plt.imread('Color.png')
    plt.imshow(bg)       
    plt.tight_layout()
    return plt.show()

# %%
img = mpimg.imread("C:/users/imagess.png")
bg = plt.imread('C:/users/imagess.png')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(160,120), dpi = 10)

#donut plot
wedges, text = ax1.pie(list_precent,
                      labels= text_c,
                      labeldistance= 1.05,
                      colors = list_color,
                      textprops={'fontsize': 160, 'color':'black'})
plt.setp(wedges, width=0.3)

#add image in the center of donut plot
imagebox = OffsetImage(img, zoom=2.3)
ab = AnnotationBbox(imagebox, (0, 0))
ax1.add_artist(ab)

#color palette
x_posi, y_posi, y_posi2 = 160, -170, -170
for c in list_color:
    if list_color.index(c) <= 5:
        y_posi += 180
        rect = patches.Rectangle((x_posi, y_posi), 360, 160, facecolor = c)
        ax2.add_patch(rect)
        ax2.text(x = x_posi+400, y = y_posi+100, s = c, fontdict={'fontsize': 190})
    else:
        y_posi2 += 180
        rect = patches.Rectangle((x_posi + 1000, y_posi2), 360, 160, facecolor = c)
        ax2.add_artist(rect)
        ax2.text(x = x_posi+1400, y = y_posi2+100, s = c, fontdict={'fontsize': 190})

ax2.axis('off')
fig.set_facecolor('white')
plt.imshow(bg)       
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [59], in <cell line: 7>()
#       4 fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(160,120), dpi = 10)
#       6 #donut plot
# ----> 7 wedges, text = ax1.pie(list_precent,
#       8                       labels= text_c,
#       9                       labeldistance= 1.05,
#      10                       colors = list_color,
#      11                       textprops={'fontsize': 160, 'color':'black'})
#      12 plt.setp(wedges, width=0.3)
#      14 #add image in the center of donut plot
#
# NameError: name 'list_precent' is not defined

# %%
list_color = list(df_color['c_code'])
list_precent = [int(i) for i in list(df_color['occurence'])]
text_c = [c + ' ' + str(round(p*100/sum(list_precent),1)) +'%' for c, p in zip(list_color,
                                                                               list_precent)]
fig, ax = plt.subplots(figsize=(90,90),dpi=10)
wedges, text = ax.pie(list_precent,
                      labels= text_c,
                      labeldistance= 1.05,
                      colors = list_color,
                      textprops={'fontsize': 120, 'color':'black'}
                     )
plt.setp(wedges, width=0.3)

#create space in the center
plt.setp(wedges, width=0.36)

ax.set_aspect("equal")
fig.set_facecolor('white')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 list_color = list(df_color['c_code'])
#       2 list_precent = [int(i) for i in list(df_color['occurence'])]
#       3 text_c = [c + ' ' + str(round(p*100/sum(list_precent),1)) +'%' for c, p in zip(list_color,
#       4                                                                                list_precent)]
#
# NameError: name 'df_color' is not defined

# %%
def color_to_df(input):
    colors_pre_list = str(input).replace('([(','').split(', (')[0:-1]
    df_rgb = [i.split('), ')[0] + ')' for i in colors_pre_list]
    df_percent = [i.split('), ')[1].replace(')','') for i in colors_pre_list]
    
    #convert RGB to HEX code
    df_color_up = [rgb2hex(int(i.split(", ")[0].replace("(","")),
                          int(i.split(", ")[1]),
                          int(i.split(", ")[2].replace(")",""))) for i in df_rgb]
    
    df = pd.DataFrame(zip(df_color_up, df_percent), columns = ['c_code','occurence'])
    return df

df_color = color_to_df(colors_x)
df_color
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 14>()
#      11     df = pd.DataFrame(zip(df_color_up, df_percent), columns = ['c_code','occurence'])
#      12     return df
# ---> 14 df_color = color_to_df(colors_x)
#      15 df_color
#
# NameError: name 'colors_x' is not defined

# %%
colors_x = extcolors.extract_from_path(img_url, tolerance = 12, limit = 12)
colors_x
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [62], in <cell line: 1>()
# ----> 1 colors_x = extcolors.extract_from_path(img_url, tolerance = 12, limit = 12)
#       2 colors_x
#
# File ~\anaconda3\lib\site-packages\extcolors\__init__.py:42, in extract_from_path(path, tolerance, limit)
#      41 def extract_from_path(path, tolerance=DEFAULT_TOLERANCE, limit=None):
# ---> 42     img = Image.open(path)
#      43     return extract_from_image(img, tolerance, limit)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\PIL\Image.py:3068, in open(fp, mode, formats)
#    3065     filename = fp
#    3067 if filename:
# -> 3068     fp = builtins.open(filename, "rb")
#    3069     exclusive_fp = True
#    3071 try:
#
# OSError: [Errno 22] Invalid argument: 'resize_F:\\Color.png'
